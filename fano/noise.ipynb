# %%
from scipy.fftpack import fft, fftfreq, fftshift
import numpy as np
import matplotlib.pyplot as plt
N = 1000
beta = 2
n = beta / 2
# sample spacing
w = np.linspace(1, 100000 , N )
R = np.random.normal(0,1,N) 
R2 = np.random.normal(0,1,N) 
f =  R*(1/w)**n + R2*(1/w)**n*1j
ff = fft(f)
wf = fftfreq(N, T)
wf = fftshift(wf)
fplot = fftshift(ff)
plt.plot(wf, np.abs(fplot))
plt.grid()
plt.figure()
plt.loglog(w,f)

# %%
N = 1000
beta = 8
n = beta / 2
# sample spacing
w = np.linspace(1, 10000 , N )
R = np.random.normal(0,1,N) 
f =  R*(1/w)**n + R2*(1/w)**n*1j
ff = np.fft.fft(f)
freq = np.fft.fftfreq(w.shape[-1])
plt.plot(freq,ff)
